# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dst= pd.read_csv('DREAM7_DrugSensitivity1_Drug_Response_Training.txt', index_col=0, header=0, sep= "\t")
dst.index.name='cell_line'
dst.reset_index(inplace=True)
dst.head(5)
# Out:
#    cell_line  Drug1  Drug2  Drug3  Drug4  Drug5  Drug6  Drug7  Drug8  Drug9  \
# 0    HCC1954  4.833  5.032  3.777    NaN  6.223    NaN  4.176  7.196  4.478
# 1      AU565  5.255  5.256  4.378    NaN  6.164    NaN  6.836  7.381  4.478
# 2    HCC1937  5.012  4.996  4.461    NaN  6.164    NaN  6.889  6.721  4.000
# 3      CAMA1  4.717  4.851  4.394  6.983  6.164  4.903  4.851  6.947  4.000
# 4  T47DKBLUC  5.166  5.186  4.004  7.277    NaN    NaN  6.996  7.013  4.000
#
#    ...  Drug22  Drug23  Drug24  Drug25  Drug26  Drug27  Drug28  Drug29  \
# 0  ...   4.951   4.804   2.724     NaN   5.478     NaN   4.523   2.520
# 1  ...   5.332   4.478   2.724   4.883   5.478   4.478   4.176   2.851
# 2  ...   5.198   4.478   2.724     NaN   5.478     NaN   3.876   2.564
# 3  ...   5.301   4.176   2.724     NaN   5.478     NaN   3.876   2.791
# 4  ...     NaN   4.478   2.724     NaN   5.478     NaN   3.876   2.762
#
#    Drug30  Drug31
# 0   6.351   6.169
# 1   6.567   6.336
# 2   6.959   6.439
# ...

# %%
ge= pd.read_csv('DREAM7_DrugSensitivity1_GeneExpression.txt', index_col=0, header=0, sep="\t")
ge=ge.transpose()
ge.index.name='cell_line'
ge.head(5)
# Out:
# HGNC_ID    C9orf152     ELMO2      RPS11   CREB3L1     PNMA1      MMP2  \
# cell_line
# 184B5      3.613030  7.205940  10.476276  5.565989  7.664038  5.108659
# 600MPE     8.463736  7.959597   9.939852  9.835957  7.645439  4.611590
# AU565      7.935823  8.073369   9.817430  5.696639  7.761882  4.765150
# BT20       3.098928  8.164778  10.038500  4.972852  7.766212  4.657057
# BT474      9.010836  8.120015   9.533423  8.155372  8.393242  4.584473
#
# HGNC_ID    C10orf90     ERCC5      ZHX3     GPR98  ...     GRIP2   GOLGA8B  \
# cell_line                                          ...
# 184B5      4.128089  7.263226  5.742329  3.671584  ...  6.164306  4.648155
# 600MPE     3.687597  7.450175  5.199320  5.755408  ...  5.716731  5.082299
# AU565      3.883901  7.204121  5.477589  6.198794  ...  6.133836  4.844242
# BT20       3.848230  7.758748  5.764572  3.560379  ...  5.777977  5.019017
# BT474      3.667176  6.542780  4.882232  4.810989  ...  5.780276  5.151477
#
# ...

# %%
ex= pd.read_csv('DREAM7_DrugSensitivity1_Exomeseq.txt', index_col=0, header=0, sep="\t")
ex.index.name='cell_line'
ex.head(5)
# Out:
#              Tissue dbSNP CancerGene?  #Cosmic      Type HGNC_ID  Summary  \
# cell_line
# 184A1      Germline     .          No        0  Missense  TTLL10  p.G112R
# 184A1      Germline     .          No        0  Missense  CPSF3L   p.T75I
# 184A1      Germline     .          No        0  Missense   CCNL2   p.R93P
# 184A1      Germline     .          No        0  Missense  ATAD3C  p.G337R
# 184A1      Germline     .          No        0  Missense  ATAD3B  p.R579C
#
#           Chromosome    Start     Stop  ... Zygosity(tumor) RefCount(tumor)  \
# cell_line                               ...
# 184A1              1  1115548  1115548  ...             het              66
# 184A1              1  1254635  1254635  ...             het              24
# 184A1              1  1334409  1334409  ...             het               6
# 184A1              1  1398008  1398008  ...             het              58
# 184A1              1  1430985  1430985  ...             hom               0
#
# ...

# %%
me= pd.read_csv('DREAM7_DrugSensitivity1_Methylation.txt', index_col=[0,1], header=0,sep="\t")
me=me.transpose()
me.index.name='cell_line'
me.head(5)
# Out:
# Illumina_ID cg00000292 cg00002426 cg00003994 cg00005847 cg00006414 cg00007981  \
# HGNC_ID         ATP2A1      SLMAP      MEOX2      HOXD3     ZNF398      PANX1
# cell_line
# CGct1         2.000000   3.000000   1.000000   1.000000   4.000000   2.000000
# Cct1         10.000000  10.000000  13.000000  12.000000   9.000000   9.000000
# 600MPE        0.881395   0.067202   0.863474   0.842265   0.084663   0.073098
# AU565         0.625653   0.056657   0.038321   0.102223   0.091306   0.035754
# BT20          0.922304   0.057735   0.541085   0.893619   0.065515   0.058254
#
# Illumina_ID cg00008493 cg00008713 cg00009407 cg00010193  ... cg27653134  \
# HGNC_ID          COX8C      IMPA2       TTC8   FLJ35816  ...      A2ML1
# cell_line                                                ...
# CGct1         4.000000   4.000000   4.000000   2.000000  ...   1.000000
# Cct1          9.000000   9.000000   9.000000  12.000000  ...   9.000000
# ...

# %%
rex= pd.read_csv('DREAM7_DrugSensitivity1_RNAseq_expressed_calls.txt', index_col=[0,1], header=0,sep="\t" )
rex=rex.transpose()
rex.index.name="cell_line"
rex.head(5)
# Out:
# HGNC_ID             TSPAN6            NFYA           ABCB4            EML1  \
# Ensembl_ID ENSG00000000003 ENSG00000001167 ENSG00000005471 ENSG00000066629
# cell_line
# 184A1                    1               1               0               1
# 184B5                    1               1               0               0
# 21MT1                    1               1               0               0
# 21NT                     1               1               0               0
# 600MPE                   1               1               0               1
#
# HGNC_ID              ABCA9           ABCA6          ABCA10           ABCA5  \
# Ensembl_ID ENSG00000154258 ENSG00000154262 ENSG00000154263 ENSG00000154265
# cell_line
# 184A1                    0               0               0               0
# 184B5                    0               0               0               1
# 21MT1                    0               0               0               0
# ...

# %%
rqt= pd.read_csv('DREAM7_DrugSensitivity1_RNAseq_quantification.txt', index_col=[0,1], header=0,sep="\t" )
rqt=rqt.transpose()
rqt.index.name="cell_line"
rqt.head(5)
# Out:
# HGNC_ID             TSPAN6            NFYA           ABCB4            EML1  \
# Ensembl_ID ENSG00000000003 ENSG00000001167 ENSG00000005471 ENSG00000066629
# cell_line
# 184A1            95.212548       89.512619        0.000000       24.701397
# 184B5            95.698676       94.154375        0.172734        7.633869
# 21MT1            19.994674      245.433541        0.231762        5.842132
# 21NT             44.057746      286.092419        0.000000        5.149179
# 600MPE          178.158832      125.193255        0.757785       29.604076
#
# HGNC_ID              ABCA9           ABCA6          ABCA10           ABCA5  \
# Ensembl_ID ENSG00000154258 ENSG00000154262 ENSG00000154263 ENSG00000154265
# cell_line
# 184A1             0.000000        0.078395        0.754157        7.832908
# 184B5             2.683498        0.444747        2.676722       28.249303
# 21MT1             0.000000        0.000000        2.047496        0.618510
# ...

# %%
rppa= pd.read_csv('DREAM7_DrugSensitivity1_RPPA.txt', index_col=[0,1], header=0,sep="\t" )
rppa=rppa.transpose()
rppa.index.name="cell_line"
rppa.head(5)
# Out:
# Antibody_ID     EIF4EBP1 EIF4EBP1-p37 EIF4EBP1-p65     NCOA3 AKT1,AKT2,AKT3  \
# FullyValidated       Yes          Yes           No        No            Yes
# cell_line
# 184A1          -0.514511    -0.602368    -0.346251  0.025026       0.514092
# 184B5           0.865465     0.021478    -0.128969  0.268660      -0.041664
# 600MPE          0.189235    -0.691073    -0.561238 -0.153393       0.648638
# AU565          -2.170981    -0.711503    -0.194758  0.064824       0.675827
# BT20           -0.174487     0.050302     0.297102  0.621607      -1.710499
#
# Antibody_ID    AKT1-p308,AKT2-p308,AKT3-p308 AKT1-p473,AKT2-p473,AKT3-p473  \
# FullyValidated                           Yes                           Yes
# cell_line
# 184A1                              -1.007596                      0.375858
# 184B5                               0.030733                      1.386861
# 600MPE                             -0.994399                     -2.063608
# ...

# %%
dst_6= pd.read_csv('DREAM7_DrugSensitivity1_SNP6.cbs', index_col=[0], header=0,sep="\t")
dst_6.index.name="cell_line"
dst_6.head(5)
# Out:
#            Chromosome      Start       Stop  Count   Mean
# cell_line
# 184B5               1      51599   72541087  44210 -0.046
# 184B5               1   72541505   72583737     46  1.675
# 184B5               1   72584492  110028494  24236 -0.027
# 184B5               1  110028841  110044477     24  1.090
# 184B5               1  110046522  143797135   7606 -0.050

# %%
dst_6g= pd.read_csv('DREAM7_DrugSensitivity1_SNP6_gene_level.txt', index_col=[0,1], header=0,sep="\t" )
dst_6g=dst_6g.transpose()
dst_6g.index.name="cell_line"
dst_6g.head(5)
# Out:
# EntrezID   403263 79501     645543    653340    643670    653341    643698  \
# HGNC_ID   OR4G11P  OR4F5 LOC645543 LOC653340 LOC643670 LOC653341 LOC643698
# cell_line
# 184B5      -0.046 -0.046    -0.046    -0.046    -0.046    -0.046    -0.046
# 21MT1       0.270  0.270     0.270     0.270     0.270     0.270     0.270
# 21NT        0.112  0.112     0.112     0.112     0.112     0.112     0.112
# 600MPE      0.332  0.332     0.332     0.332     0.005     0.005     0.005
# AU565      -0.136 -0.136    -0.136    -0.136    -0.136    -0.136    -0.136
#
# EntrezID     440550    653345    440551  ...   375775 64975    92715   116225  \
# HGNC_ID   LOC440550 LOC653345 LOC440551  ... C9orf111 MRPL41 C9orf112 ZMYND19
# cell_line                                ...
# 184B5        -0.046    -0.046    -0.046  ...   -0.046 -0.046   -0.046  -0.046
# 21MT1         0.270     0.270     0.270  ...   -0.035 -0.035   -0.035  -0.035
# ...
